# %%
import importlib
import gantt_anywidget
importlib.reload(gantt_anywidget)
# Out:
# <module 'gantt_anywidget' from 'C:\\Users\\hatch\\OneDrive\\Documents\\GanttSketch\\gantt_anywidget.py'>

# %%
from gantt_anywidget import GanttWidget
w = GanttWidget(height="800px", width="100%")
w
